# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"../data/diabetes_dataset.csv")
dataset.head()
# Out:
#    age  gender ethnicity education_level  income_level employment_status  \
# 0   58    Male     Asian      Highschool  Lower-Middle          Employed
# 1   48  Female     White      Highschool        Middle          Employed
# 2   60    Male  Hispanic      Highschool        Middle        Unemployed
# 3   74  Female     Black      Highschool           Low           Retired
# 4   46    Male     White        Graduate        Middle           Retired
#
#   smoking_status  alcohol_consumption_per_week  \
# 0          Never                             0
# 1         Former                             1
# 2          Never                             1
# 3          Never                             0
# 4          Never                             1
#
#    physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                 215         5.7  ...               41
# 1                                 143         6.7  ...               55
# ...

# %%
train_data = pd.read_csv(r"../data/train.csv")
train_data.head()
# Out:
#    id  age  alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0   0   31                             1                                  45
# 1   1   50                             2                                  73
# 2   2   32                             3                                 158
# 3   3   54                             3                                  77
# 4   4   54                             1                                  55
#
#    diet_score  sleep_hours_per_day  screen_time_hours_per_day   bmi  \
# 0         7.7                  6.8                        6.1  33.4
# 1         5.7                  6.5                        5.8  23.8
# 2         8.5                  7.4                        9.1  24.1
# 3         4.6                  7.0                        9.2  26.6
# 4         5.7                  6.2                        5.1  28.8
#
#    waist_to_hip_ratio  systolic_bp  ...  gender  ethnicity  education_level  \
# ...

# %%
extra_features = [
    col
    for col in dataset.columns
    if col not in train_data.columns and col != "id"
]

extra_features
# Out:
# ['glucose_fasting',
#  'glucose_postprandial',
#  'insulin_level',
#  'hba1c',
#  'diabetes_risk_score',
#  'diabetes_stage']

# %%
dataset_columns = dataset.columns
train_data_columns = train_data.columns

# %%
list(set(dataset_columns) ^ set(train_data_columns))
# Out:
# ['glucose_postprandial',
#  'id',
#  'diabetes_stage',
#  'hba1c',
#  'insulin_level',
#  'glucose_fasting',
#  'diabetes_risk_score']

# %%
list(set(dataset_columns) - set(train_data_columns))
# Out:
# ['glucose_postprandial',
#  'insulin_level',
#  'glucose_fasting',
#  'diabetes_risk_score',
#  'diabetes_stage',
#  'hba1c']

# %%
list(set(train_data_columns) - set(dataset_columns))
# Out:
# ['id']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 100000 non-null  int64
#  1   gender                              100000 non-null  object
#  2   ethnicity                           100000 non-null  object
#  3   education_level                     100000 non-null  object
#  4   income_level                        100000 non-null  object
#  5   employment_status                   100000 non-null  object
#  6   smoking_status                      100000 non-null  object
#  7   alcohol_consumption_per_week        100000 non-null  int64
#  8   physical_activity_minutes_per_week  100000 non-null  int64
#  9   diet_score                          100000 non-null  float64
#  10  sleep_hours_per_day                 100000 non-null  float64
# ...

# %%
final_train_data = pd.concat([train_data, dataset], join="inner", ignore_index=True)

# %%
final_train_data['family_history_diabetes'].value_counts()
# Out:
# family_history_diabetes
# 0    673478
# 1    126522
# Name: count, dtype: int64
